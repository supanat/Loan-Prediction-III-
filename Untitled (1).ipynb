# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_auc_score, accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('Train.csv')

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status            int64
# dtype: object

# %%
X = df.iloc[:,1:-1].reset_index(drop = True)
X
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# 6      Male     Yes          0  Not Graduate            No             2333
# 7      Male     Yes         3+      Graduate            No             3036
# 8      Male     Yes          2      Graduate            No             4006
# 9      Male     Yes          1      Graduate            No            12841
# 10     Male     Yes          2      Graduate            No             3200
# ...

# %%
df['Loan_Status'].dtypes
# Out:
# dtype('int64')

# %%
df['Loan_Status'].replace(['Y','N'],[1,0],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-cf7d14e03c88> in <module>()
# ----> 1 df['Loan_Status'].replace(['Y','N'],[1,0],inplace=True)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3429         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3430                                            inplace=inplace, limit=limit,
# -> 3431                                            regex=regex, method=method)
#    3432
#    3433     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5845                                                        dest_list=value,
# ...

# %%
print(df.shape)
print(df.dropna().shape)
# Out:
# (614, 13)
# (480, 13)

# %%
# Find the columns where each value is null
empty_cols = [col for col in df.columns if df[col].isnull().all()]

# Drop these columns from the dataframe
df.drop(empty_cols,
        axis=1,
        inplace=True)

# %%
print(df.shape)
# Out:
# (614, 13)

# %%
df.Loan_Status.value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
zero_cls = Y[Y.Loan_Status == 'Y']
one_cls = df[df.Loan_Status == 'N']

# %%
#zero_cls = zero_cls.sample(frac=1).reset_index(drop = True)
#zero_cls = zero_cls.iloc[:one_cls.shape[0],:]

# %%
#under_sampling_df = pd.concat([one_cls, zero_cls]).reset_index(drop=True)
#under_sampling_df = under_sampling_df.sample(frac=1)

# %%
#under_sampling_df.Loan_Status.value_counts()

# %%
#X = under_sampling_df.iloc[:,4:].reset_index(drop = True)
#y = under_sampling_df.iloc[:,3].reset_index(drop = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state=2019)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-41a463b4066b> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state=2019)
#
# NameError: name 'X' is not defined
